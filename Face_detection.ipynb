# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
image = cv2.imread('image/bong.png')
grayImage = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

plt.figure(figsize=(12,8))
plt.imshow(grayImage, cmap='gray')
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()

# %%
#xml = 'haarcascades/haarcascade_frontalface_alt.xml'
xml = 'haarcascades/haarcascade_frontalface_alt2.xml'

face_cascade = cv2.CascadeClassifier(xml)

#faces = face_cascade.detectMultiScale(grayImage, 1.1, 5)
faces = face_cascade.detectMultiScale(grayImage, 1.05, 5)

print("Number of faces detected: " + str(len(faces)))

t = image.copy()

for (x,y,w,h) in faces:
    cv2.rectangle(t,(x,y),(x+w,y+h),(0,255,0),2)

cv2.putText(t, "test", (0,image.shape[0] -10), 
            cv2.FONT_HERSHEY_TRIPLEX, 0.5,  (0,0,0), 1);

plt.figure(figsize=(12,12))
plt.imshow(t, cmap='gray')
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()
# Out:
# Number of faces detected: 2
